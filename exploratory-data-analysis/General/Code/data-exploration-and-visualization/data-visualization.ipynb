# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_pickle(r"D:\Coding\Data-Prep-EDA\Code\Data\groceries_with_new_columns.pkl")
df.head()
# Out:
#   Product_ID  Product_ID_Num Category Subcategory                  Item  \
# 0    P100010          100010  Produce       Fruit                 Apple
# 1    P100011          100011  Produce       Fruit                Banana
# 2    P100012          100012  Produce       Fruit                Grapes
# 3    P100013          100013  Produce       Fruit            Grapefruit
# 4    P100014          100014  Produce       Fruit  Organic Strawberries
#
#    Organic  Price_Dollars  Inventory  Percent Inventory Low Inventory  \
# 0    False           1.50        349                7.2
# 1    False           0.40        500               10.3
# 2    False           4.00        200                4.1
# 3    False           0.99         50                1.0
# 4     True           3.99        148                3.0
#
#          Last_Updated Last_Updated_Time Next_Scheduled_Shipment  \
# 0 2023-06-12 15:35:00          15:35:00              2023-06-15
# ...

# %%
df.groupby("Subcategory")["Price_Dollars"].mean()
# Out:
# Subcategory
# Dairy            3.070000
# Frozen Fruit     9.475000
# Frozen Snacks    5.975000
# Fruit            2.811667
# Meat             9.156667
# Snacks           3.095000
# Vegetable        1.690000
# Name: Price_Dollars, dtype: float64

# %%
df.groupby("Subcategory")["Price_Dollars"].mean().plot.bar()
# Out:
# <Axes: xlabel='Subcategory'>

# %%
df.groupby("Subcategory")["Price_Dollars"].mean().plot.barh()
# Out:
# <Axes: ylabel='Subcategory'>

# %%
df.groupby("Subcategory")["Price_Dollars"].mean().sort_values().plot.barh()
# Out:
# <Axes: ylabel='Subcategory'>

# %%
happiness_df = pd.read_csv(r"D:\Coding\Data-Prep-EDA\Code\Data\happiness_survey_data.csv")
happiness_df.head()
# Out:
#   country_name  year  happiness_score  social_support  \
# 0  Afghanistan  2008         3.723590        0.450662
# 1  Afghanistan  2009         4.401778        0.552308
# 2  Afghanistan  2010         4.758381        0.539075
# 3  Afghanistan  2011         3.831719        0.521104
# 4  Afghanistan  2012         3.782938        0.520637
#
#    freedom_to_make_life_choices  healthy_life_expectancy_at_birth
# 0                      0.718114                         50.500000
# 1                      0.678896                         50.799999
# 2                      0.600127                         51.099998
# 3                      0.495901                         51.400002
# 4                      0.530935                         51.700001

# %%
happiness_df[happiness_df.country_name == "Mexico"]
# Out:
#      country_name  year  happiness_score  social_support  \
# 1187       Mexico  2005         6.580658        0.902808
# 1188       Mexico  2007         6.525378        0.878806
# 1189       Mexico  2008         6.829036        0.876328
# 1190       Mexico  2009         6.962819        0.868221
# 1191       Mexico  2010         6.802389        0.876390
# 1192       Mexico  2011         6.909515        0.824064
# 1193       Mexico  2012         7.320185        0.767279
# 1194       Mexico  2013         7.442546        0.759138
# 1195       Mexico  2014         6.679831        0.781965
# 1196       Mexico  2015         6.236287        0.760614
# 1197       Mexico  2016         6.824173        0.893493
# 1198       Mexico  2017         6.410299        0.799839
# 1199       Mexico  2018         6.549579        0.858069
# 1200       Mexico  2019         6.431945        0.851686
# 1201       Mexico  2020         5.964221        0.778816
# ...

# %%
happiness_df[happiness_df.country_name == "Mexico"].iloc[:, 1:3]
# Out:
#       year  happiness_score
# 1187  2005         6.580658
# 1188  2007         6.525378
# 1189  2008         6.829036
# 1190  2009         6.962819
# 1191  2010         6.802389
# 1192  2011         6.909515
# 1193  2012         7.320185
# 1194  2013         7.442546
# 1195  2014         6.679831
# 1196  2015         6.236287
# 1197  2016         6.824173
# 1198  2017         6.410299
# 1199  2018         6.549579
# 1200  2019         6.431945
# 1201  2020         5.964221
# 1202  2021         5.990751

# %%
happiness_df[happiness_df.country_name == "Mexico"].iloc[:, 1:3].plot.line(x="year", y="happiness_score")
# Out:
# <Axes: xlabel='year'>

# %%
happiness_df[happiness_df.country_name.isin(["Canada","Mexico", "United States"])].iloc[:, :3]
# Out:
#        country_name  year  happiness_score
# 310          Canada  2005         7.418048
# 311          Canada  2007         7.481753
# 312          Canada  2008         7.485604
# 313          Canada  2009         7.487824
# 314          Canada  2010         7.650346
# 315          Canada  2011         7.426054
# 316          Canada  2012         7.415144
# 317          Canada  2013         7.593794
# 318          Canada  2014         7.304258
# 319          Canada  2015         7.412773
# 320          Canada  2016         7.244846
# 321          Canada  2017         7.414868
# 322          Canada  2018         7.175497
# 323          Canada  2019         7.109076
# 324          Canada  2020         7.024905
# 325          Canada  2021         6.939435
# 1187         Mexico  2005         6.580658
# 1188         Mexico  2007         6.525378
# 1189         Mexico  2008         6.829036
# 1190         Mexico  2009         6.962819
# 1191         Mexico  2010         6.802389
# ...

# %%
(happiness_df[happiness_df.country_name.isin(["Canada","Mexico", "United States"])]
.iloc[:, :3]
.pivot(index="year", columns="country_name", values="happiness_score"))
# Out:
# country_name    Canada    Mexico  United States
# year
# 2005          7.418048  6.580658            NaN
# 2006               NaN       NaN       7.181794
# 2007          7.481753  6.525378       7.512688
# 2008          7.485604  6.829036       7.280386
# 2009          7.487824  6.962819       7.158032
# 2010          7.650346  6.802389       7.163616
# 2011          7.426054  6.909515       7.115139
# 2012          7.415144  7.320185       7.026227
# 2013          7.593794  7.442546       7.249285
# 2014          7.304258  6.679831       7.151114
# 2015          7.412773  6.236287       6.863947
# 2016          7.244846  6.824173       6.803600
# 2017          7.414868  6.410299       6.991759
# 2018          7.175497  6.549579       6.882685
# 2019          7.109076  6.431945       6.943701
# 2020          7.024905  5.964221       7.028088
# 2021          6.939435  5.990751       6.959088

# %%
(happiness_df[happiness_df.country_name.isin(["Canada","Mexico", "United States"])]
.iloc[:, :3]
.pivot(index="year", columns="country_name", values="happiness_score")).plot.line()
# Out:
# <Axes: xlabel='year'>

# %%
student_data = pd.read_csv(r"D:\Coding\Data-Prep-EDA\Code\Data\student_data.csv")
student_data.head()
# Out:
#    Hours of Sleep  Hours Studied  Grade on Test  Grade in Class  \
# 0       10.602667       4.586892             99       99.187294
# 1        8.172997       4.405120             72       67.070903
# 2        6.430132       0.519630             52       39.644696
# 3        7.963793       5.004348             80       61.843705
# 4        8.279421       2.984489             87      103.495002
#
#    Cups of Coffee
# 0               5
# 1               3
# 2               4
# 3               1
# 4               0

# %%
sns.pairplot(student_data)
