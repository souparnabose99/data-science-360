# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Coding\Data-Prep-EDA\Code\Data\student_data.csv")
df.head()
# Out:
#    Hours of Sleep  Hours Studied  Grade on Test  Grade in Class  \
# 0       10.602667       4.586892             99       99.187294
# 1        8.172997       4.405120             72       67.070903
# 2        6.430132       0.519630             52       39.644696
# 3        7.963793       5.004348             80       61.843705
# 4        8.279421       2.984489             87      103.495002
#
#    Cups of Coffee
# 0               5
# 1               3
# 2               4
# 3               1
# 4               0

# %%
df["Cups of Coffee"].value_counts().sort_index()
# Out:
# Cups of Coffee
# 0     35
# 1     67
# 2     44
# 3     38
# 4      6
# 5      5
# 6      3
# 8      1
# 10     1
# Name: count, dtype: int64

# %%
sns.histplot(df["Cups of Coffee"])
# Out:
# <Axes: xlabel='Cups of Coffee', ylabel='Count'>

# %%
df["Hours Studied"].round().value_counts().sort_index()
# Out:
# Hours Studied
# 0.0     4
# 1.0    18
# 2.0    23
# 3.0    53
# 4.0    38
# 5.0    37
# 6.0    19
# 7.0     7
# 8.0     1
# Name: count, dtype: int64

# %%
sns.histplot(df["Hours Studied"])
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Count'>

# %%
sns.histplot(df["Hours Studied"], bins=30)
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Count'>

# %%
songs = pd.read_csv(r"D:\Coding\Data-Prep-EDA\Code\Data\spotify_songs.csv")
songs.head()
# Out:
#                            name       artists  energy  key  mode  valence  \
# 0                    God's Plan         Drake   0.449    7     1    0.357
# 1                          SAD!  XXXTENTACION   0.613    8     1    0.473
# 2    rockstar (feat. 21 Savage)   Post Malone   0.535    5     0    0.140
# 3  Psycho (feat. Ty Dolla $ign)   Post Malone   0.559    8     1    0.439
# 4                In My Feelings         Drake   0.626    1     1    0.350
#
#      tempo  duration_ms
# 0   77.169       198973
# 1   75.023       166606
# 2  159.847       218147
# 3  140.124       221440
# 4   91.030       217925

# %%
songs.shape
# Out:
# (100, 8)

# %%
sns.pairplot(songs)

# %%
sns.histplot(songs.tempo)
# Out:
# <Axes: xlabel='tempo', ylabel='Count'>

# %%
sns.histplot(songs.tempo, bins=15)
# Out:
# <Axes: xlabel='tempo', ylabel='Count'>

# %%
songs.tempo.round(-1).value_counts().sort_index()
# Out:
# tempo
# 60.0      1
# 80.0      5
# 90.0     16
# 100.0    19
# 110.0     6
# 120.0    12
# 130.0    12
# 140.0    10
# 150.0     7
# 160.0     3
# 170.0     3
# 180.0     4
# 190.0     1
# 200.0     1
# Name: count, dtype: int64

# %% [markdown]
# ### Scatterplot:
