# %% [markdown]
# ### Append:

# %%
import numpy as np
import pandas as pd

# %%
ca = pd.read_csv(r"D:\Coding\Data-Prep-EDA\Code\Data\happiness_data_ca.txt")
cr = pd.read_csv(r"D:\Coding\Data-Prep-EDA\Code\Data\happiness_data_cr.txt")
mx = pd.read_csv(r"D:\Coding\Data-Prep-EDA\Code\Data\happiness_data_mx.txt")
us = pd.read_csv(r"D:\Coding\Data-Prep-EDA\Code\Data\happiness_data_us.txt")

# %%
ca.head()
# Out:
#   country_name  year  happiness_score  social_support  \
# 0       Canada  2005         7.418048        0.961552
# 1       Canada  2007         7.481753             NaN
# 2       Canada  2008         7.485604        0.938707
# 3       Canada  2009         7.487824        0.942845
# 4       Canada  2010         7.650346        0.953765
#
#    freedom_to_make_life_choices  healthy_life_expectancy_at_birth
# 0                      0.957306                         70.500000
# 1                      0.930341                         70.620003
# 2                      0.926315                         70.680000
# 3                      0.915058                         70.739998
# 4                      0.933949                         70.800003

# %%
cr.head()
# Out:
#   nombre del país  year  happiness_score  social_support  \
# 0      Costa Rica  2006         7.082465        0.936938
# 1      Costa Rica  2007         7.432132        0.917678
# 2      Costa Rica  2008         6.850680        0.915759
# 3      Costa Rica  2009         7.614929        0.899782
# 4      Costa Rica  2010         7.271054        0.915141
#
#    freedom_to_make_life_choices  healthy_life_expectancy_at_birth
# 0                      0.882420                         68.559998
# 1                      0.922736                         68.720001
# 2                      0.912006                         68.879997
# 3                      0.886061                         69.040001
# 4                      0.881030                         69.199997

# %%
mx.head()
# Out:
#   country_name  year  happiness_score  social_support  \
# 0       Mexico  2005         6.580658        0.902808
# 1       Mexico  2007         6.525378        0.878806
# 2       Mexico  2008         6.829036        0.876328
# 3       Mexico  2009         6.962819        0.868221
# 4       Mexico  2010         6.802389        0.876390
#
#    freedom_to_make_life_choices  healthy_life_expectancy_at_birth
# 0                      0.813745                         64.400002
# 1                      0.670430                         64.680000
# 2                      0.677477                         64.820000
# 3                      0.682463                         64.959999
# 4                      0.778121                         65.099998

# %%
us.head()
# Out:
#     country_name  year  happiness_score  social_support  \
# 0  United States  2006         7.181794        0.964572
# 1  United States  2007         7.512688             NaN
# 2  United States  2008         7.280386        0.952587
# 3  United States  2009         7.158032        0.911794
# 4  United States  2010         7.163616        0.926159
#
#    freedom_to_make_life_choices
# 0                      0.911496
# 1                      0.871904
# 2                      0.877956
# 3                      0.830684
# 4                      0.828044

# %%
pd.concat([ca, mx]).head()
# Out:
#   country_name  year  happiness_score  social_support  \
# 0       Canada  2005         7.418048        0.961552
# 1       Canada  2007         7.481753             NaN
# 2       Canada  2008         7.485604        0.938707
# 3       Canada  2009         7.487824        0.942845
# 4       Canada  2010         7.650346        0.953765
#
#    freedom_to_make_life_choices  healthy_life_expectancy_at_birth
# 0                      0.957306                         70.500000
# 1                      0.930341                         70.620003
# 2                      0.926315                         70.680000
# 3                      0.915058                         70.739998
# 4                      0.933949                         70.800003

# %%
pd.concat([ca, mx]).tail()
# Out:
#    country_name  year  happiness_score  social_support  \
# 11       Mexico  2017         6.410299        0.799839
# 12       Mexico  2018         6.549579        0.858069
# 13       Mexico  2019         6.431945        0.851686
# 14       Mexico  2020         5.964221        0.778816
# 15       Mexico  2021         5.990751        0.778605
#
#     freedom_to_make_life_choices  healthy_life_expectancy_at_birth
# 11                      0.861405                         65.800003
# 12                      0.816200                         65.800003
# 13                      0.903384                         65.800003
# 14                      0.873347                         65.800003
# 15                      0.837159                         65.800003

# %%
pd.concat([ca, mx, us]).tail()
# Out:
#      country_name  year  happiness_score  social_support  \
# 11  United States  2017         6.991759        0.921003
# 12  United States  2018         6.882685        0.903856
# 13  United States  2019         6.943701        0.916691
# 14  United States  2020         7.028088        0.937370
# 15  United States  2021         6.959088        0.920009
#
#     freedom_to_make_life_choices  healthy_life_expectancy_at_birth
# 11                      0.868497                               NaN
# 12                      0.824607                               NaN
# 13                      0.836139                               NaN
# 14                      0.850447                               NaN
# 15                      0.815735                               NaN

# %%
pd.concat([ca, mx, us]).head()
# Out:
#   country_name  year  happiness_score  social_support  \
# 0       Canada  2005         7.418048        0.961552
# 1       Canada  2007         7.481753             NaN
# 2       Canada  2008         7.485604        0.938707
# 3       Canada  2009         7.487824        0.942845
# 4       Canada  2010         7.650346        0.953765
#
#    freedom_to_make_life_choices  healthy_life_expectancy_at_birth
# 0                      0.957306                         70.500000
# 1                      0.930341                         70.620003
# 2                      0.926315                         70.680000
# 3                      0.915058                         70.739998
# 4                      0.933949                         70.800003

# %%
pd.concat([ca, mx, us,cr]).head()
# Out:
#   country_name  year  happiness_score  social_support  \
# 0       Canada  2005         7.418048        0.961552
# 1       Canada  2007         7.481753             NaN
# 2       Canada  2008         7.485604        0.938707
# 3       Canada  2009         7.487824        0.942845
# 4       Canada  2010         7.650346        0.953765
#
#    freedom_to_make_life_choices  healthy_life_expectancy_at_birth  \
# 0                      0.957306                         70.500000
# 1                      0.930341                         70.620003
# 2                      0.926315                         70.680000
# 3                      0.915058                         70.739998
# 4                      0.933949                         70.800003
#
#   nombre del país
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
pd.concat([ca, mx, us, cr]).tail()
# Out:
#    country_name  year  happiness_score  social_support  \
# 11          NaN  2017         7.225182        0.921697
# 12          NaN  2018         7.141075        0.875872
# 13          NaN  2019         6.997619        0.906077
# 14          NaN  2020         6.338472        0.834200
# 15          NaN  2021         6.408448        0.876052
#
#     freedom_to_make_life_choices  healthy_life_expectancy_at_birth  \
# 11                      0.935618                              70.0
# 12                      0.941888                              70.0
# 13                      0.926830                              70.0
# 14                      0.889400                              70.0
# 15                      0.886652                              70.0
#
#    nombre del país
# 11      Costa Rica
# 12      Costa Rica
# 13      Costa Rica
# 14      Costa Rica
# 15      Costa Rica

# %%
pd.concat([ca, mx, us, cr.rename(columns = {'nombre del país': 'country_name'})]).head()
# Out:
#   country_name  year  happiness_score  social_support  \
# 0       Canada  2005         7.418048        0.961552
# 1       Canada  2007         7.481753             NaN
# 2       Canada  2008         7.485604        0.938707
# 3       Canada  2009         7.487824        0.942845
# 4       Canada  2010         7.650346        0.953765
#
#    freedom_to_make_life_choices  healthy_life_expectancy_at_birth
# 0                      0.957306                         70.500000
# 1                      0.930341                         70.620003
# 2                      0.926315                         70.680000
# 3                      0.915058                         70.739998
# 4                      0.933949                         70.800003

# %%
pd.concat([ca, mx, us, cr.rename(columns = {'nombre del país': 'country_name'})]).reset_index().tail()
# Out:
#     index country_name  year  happiness_score  social_support  \
# 59     11   Costa Rica  2017         7.225182        0.921697
# 60     12   Costa Rica  2018         7.141075        0.875872
# 61     13   Costa Rica  2019         6.997619        0.906077
# 62     14   Costa Rica  2020         6.338472        0.834200
# 63     15   Costa Rica  2021         6.408448        0.876052
#
#     freedom_to_make_life_choices  healthy_life_expectancy_at_birth
# 59                      0.935618                              70.0
# 60                      0.941888                              70.0
# 61                      0.926830                              70.0
# 62                      0.889400                              70.0
# 63                      0.886652                              70.0

# %% [markdown]
# ### Join:

# %%
sales_may = pd.read_excel(r"D:\Coding\Data-Prep-EDA\Code\Data\Sales Tables.xlsx", sheet_name=0)
sales_june = pd.read_excel(r"D:\Coding\Data-Prep-EDA\Code\Data\Sales Tables.xlsx", sheet_name=1)
regions = pd.read_excel(r"D:\Coding\Data-Prep-EDA\Code\Data\Sales Tables.xlsx", sheet_name=2)

# %%
sales_may.head()
# Out:
#         date  store  sales
# 0 2022-05-01      1    341
# 1 2022-05-01      2    291
# 2 2022-05-01      3    493
# 3 2022-05-01      4    428
# 4 2022-05-01      5    152

# %%
sales_june.head()
# Out:
#         date  store  sales
# 0 2022-06-01      1     67
# 1 2022-06-01      2    144
# 2 2022-06-01      3    226
# 3 2022-06-01      4    397
# 4 2022-06-01      5    163

# %%
regions.head()
# Out:
#    store region
# 0      2  North
# 1      3   East
# 2      4   West
# 3      8  South

# %%
# Default join is 'inner' #
sales_may.merge(regions)
# Out:
#         date  store  sales region
# 0 2022-05-01      2    291  North
# 1 2022-05-01      3    493   East
# 2 2022-05-01      4    428   West

# %%
sales_may.merge(regions, how='left', left_on='store', right_on='store')
# Out:
#         date  store  sales region
# 0 2022-05-01      1    341    NaN
# 1 2022-05-01      2    291  North
# 2 2022-05-01      3    493   East
# 3 2022-05-01      4    428   West
# 4 2022-05-01      5    152    NaN

# %%
sales_may.merge(regions, how='left')
# Out:
#         date  store  sales region
# 0 2022-05-01      1    341    NaN
# 1 2022-05-01      2    291  North
# 2 2022-05-01      3    493   East
# 3 2022-05-01      4    428   West
# 4 2022-05-01      5    152    NaN

# %%
sales_may.merge(regions, how='left', on='store')
# Out:
#         date  store  sales region
# 0 2022-05-01      1    341    NaN
# 1 2022-05-01      2    291  North
# 2 2022-05-01      3    493   East
# 3 2022-05-01      4    428   West
# 4 2022-05-01      5    152    NaN
