# %% [markdown]
# ### Numeric Columns:

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel(r"D:\Coding\Data-Prep-EDA\Code\Data\Groceries.xlsx")
df.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory  \
# 0    P100010  Produce: Fruit                 Apple           1.50        349
# 1    P100011  Produce: Fruit                Banana           0.40        500
# 2    P100012  Produce: Fruit                Grapes           4.00        200
# 3    P100013  Produce: Fruit            Grapefruit           0.99         50
# 4    P100014  Produce: Fruit  Organic Strawberries           3.99        148
#
#          Last_Updated Next_Scheduled_Shipment
# 0 2023-06-12 15:35:00              2023-06-15
# 1 2023-06-12 18:30:00              2023-06-15
# 2 2023-06-12 17:22:00              2023-06-15
# 3 2023-06-12 16:29:00              2023-06-15
# 4 2023-06-12 18:10:00              2023-06-15

# %%
df["Total Inventory"] = df.Inventory.sum()
df["Precent Inventory"] =  round(df.Inventory /df["Total Inventory"] * 100, 2)
df.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory  \
# 0    P100010  Produce: Fruit                 Apple           1.50        349
# 1    P100011  Produce: Fruit                Banana           0.40        500
# 2    P100012  Produce: Fruit                Grapes           4.00        200
# 3    P100013  Produce: Fruit            Grapefruit           0.99         50
# 4    P100014  Produce: Fruit  Organic Strawberries           3.99        148
#
#          Last_Updated Next_Scheduled_Shipment  Total Inventory  \
# 0 2023-06-12 15:35:00              2023-06-15             4857
# 1 2023-06-12 18:30:00              2023-06-15             4857
# 2 2023-06-12 17:22:00              2023-06-15             4857
# 3 2023-06-12 16:29:00              2023-06-15             4857
# 4 2023-06-12 18:10:00              2023-06-15             4857
#
#    Precent Inventory
# 0               7.19
# 1              10.29
# 2               4.12
# 3               1.03
# ...

# %% [markdown]
# ### DateTime Columns:

# %%
df["Last Updated Time"] = df["Last_Updated"].dt.time
df.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory  \
# 0    P100010  Produce: Fruit                 Apple           1.50        349
# 1    P100011  Produce: Fruit                Banana           0.40        500
# 2    P100012  Produce: Fruit                Grapes           4.00        200
# 3    P100013  Produce: Fruit            Grapefruit           0.99         50
# 4    P100014  Produce: Fruit  Organic Strawberries           3.99        148
#
#          Last_Updated Next_Scheduled_Shipment  Total Inventory  \
# 0 2023-06-12 15:35:00              2023-06-15             4857
# 1 2023-06-12 18:30:00              2023-06-15             4857
# 2 2023-06-12 17:22:00              2023-06-15             4857
# 3 2023-06-12 16:29:00              2023-06-15             4857
# 4 2023-06-12 18:10:00              2023-06-15             4857
#
#    Precent Inventory Last Updated Time
# 0               7.19          15:35:00
# 1              10.29          18:30:00
# ...

# %%
df["Shipment DOW"] = df["Next_Scheduled_Shipment"].dt.dayofweek
df.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory  \
# 0    P100010  Produce: Fruit                 Apple           1.50        349
# 1    P100011  Produce: Fruit                Banana           0.40        500
# 2    P100012  Produce: Fruit                Grapes           4.00        200
# 3    P100013  Produce: Fruit            Grapefruit           0.99         50
# 4    P100014  Produce: Fruit  Organic Strawberries           3.99        148
#
#          Last_Updated Next_Scheduled_Shipment  Total Inventory  \
# 0 2023-06-12 15:35:00              2023-06-15             4857
# 1 2023-06-12 18:30:00              2023-06-15             4857
# 2 2023-06-12 17:22:00              2023-06-15             4857
# 3 2023-06-12 16:29:00              2023-06-15             4857
# 4 2023-06-12 18:10:00              2023-06-15             4857
#
#    Precent Inventory Last Updated Time  Shipment DOW
# 0               7.19          15:35:00             3
# ...

# %%
df.Next_Scheduled_Shipment + pd.to_timedelta(1, "D")
# Out:
# 0    2023-06-16
# 1    2023-06-16
# 2    2023-06-16
# 3    2023-06-16
# 4    2023-06-16
# 5    2023-06-16
# 6    2023-06-16
# 7    2023-06-16
# 8    2023-06-16
# 9    2023-06-16
# 10   2023-06-18
# 11   2023-06-18
# 12   2023-06-18
# 13   2023-06-18
# 14   2023-06-18
# 15   2023-06-18
# 16   2023-06-18
# 17   2023-06-25
# 18   2023-06-25
# 19   2023-06-25
# 20   2023-06-25
# 21   2023-06-29
# 22   2023-06-29
# 23   2023-06-29
# 24   2023-06-29
# Name: Next_Scheduled_Shipment, dtype: datetime64[ns]

# %% [markdown]
# ### Text Columns:

# %%
df.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory  \
# 0    P100010  Produce: Fruit                 Apple           1.50        349
# 1    P100011  Produce: Fruit                Banana           0.40        500
# 2    P100012  Produce: Fruit                Grapes           4.00        200
# 3    P100013  Produce: Fruit            Grapefruit           0.99         50
# 4    P100014  Produce: Fruit  Organic Strawberries           3.99        148
#
#          Last_Updated Next_Scheduled_Shipment  Total Inventory  \
# 0 2023-06-12 15:35:00              2023-06-15             4857
# 1 2023-06-12 18:30:00              2023-06-15             4857
# 2 2023-06-12 17:22:00              2023-06-15             4857
# 3 2023-06-12 16:29:00              2023-06-15             4857
# 4 2023-06-12 18:10:00              2023-06-15             4857
#
#    Precent Inventory Last Updated Time  Shipment DOW
# 0               7.19          15:35:00             3
# ...

# %%
df["Product_ID_Num"] = df.Product_ID.str[1:]
df.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory  \
# 0    P100010  Produce: Fruit                 Apple           1.50        349
# 1    P100011  Produce: Fruit                Banana           0.40        500
# 2    P100012  Produce: Fruit                Grapes           4.00        200
# 3    P100013  Produce: Fruit            Grapefruit           0.99         50
# 4    P100014  Produce: Fruit  Organic Strawberries           3.99        148
#
#          Last_Updated Next_Scheduled_Shipment  Total Inventory  \
# 0 2023-06-12 15:35:00              2023-06-15             4857
# 1 2023-06-12 18:30:00              2023-06-15             4857
# 2 2023-06-12 17:22:00              2023-06-15             4857
# 3 2023-06-12 16:29:00              2023-06-15             4857
# 4 2023-06-12 18:10:00              2023-06-15             4857
#
#    Precent Inventory Last Updated Time  Shipment DOW Product_ID_Num
# ...

# %%
category_list = df.Category.str.split(":").to_list()
category_list
# Out:
# [['Produce', ' Fruit'],
#  ['Produce', ' Fruit'],
#  ['Produce', ' Fruit'],
#  ['Produce', ' Fruit'],
#  ['Produce', ' Fruit'],
#  ['Produce', ' Fruit'],
#  ['Produce', ' Vegetable'],
#  ['Produce', ' Vegetable'],
#  ['Produce', ' Vegetable'],
#  ['Produce', ' Vegetable'],
#  ['Produce', ' Meat'],
#  ['Produce', ' Meat'],
#  ['Produce', ' Meat'],
#  ['Produce', ' Dairy'],
#  ['Produce', ' Dairy'],
#  ['Produce', ' Dairy'],
#  ['Produce', ' Dairy'],
#  ['Pantry', ' Snacks'],
#  ['Pantry', ' Snacks'],
#  ['Pantry', ' Snacks'],
#  ['Pantry', ' Snacks'],
#  ['Frozen', ' Frozen Snacks'],
#  ['Frozen', ' Frozen Snacks'],
#  ['Frozen', ' Frozen Fruit'],
#  ['Frozen', ' Frozen Fruit']]

# %%
new_df = pd.DataFrame(data=category_list)
new_df.head()
# Out:
#          0       1
# 0  Produce   Fruit
# 1  Produce   Fruit
# 2  Produce   Fruit
# 3  Produce   Fruit
# 4  Produce   Fruit
